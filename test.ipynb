# %%
import pandas as pd

# %%
df = pd.read_csv('questions_output.csv')

# %%
df.head()
# Out:
#    question_no                                           question  \
# 0            1  A neuron with 4 inputs has a weight vector w =...
# 1            2     The equations 3x – y ≥ 3 and 4x – 4y ≥ 4, have
# 2            3  Which of the following manages the switching f...
# 3            4  Consider the following two statements.\nS1 : I...
# 4            5                               Match the following:
#
#                                option_a                              option_b  \
# 0                                    59                                    56
# 1        solution for positive x and y.     no solution for positive x and y.
# 2                                   BSS                                   MSC
# 3  S1 is correct but S2 is not correct.  S1 is not correct but S2 is correct.
# 4    (a)–(4), (b)–(3), (c)–(1), (d)–(2)    (a)–(2), (b)–(3), (c)–(1), (d)–(4)
#
#                              option_c                            option_d  \
# ...

# %%
df['topic'].value_counts()
# Out:
# topic
# Data Structures                                                     6
# Data Warehousing and Data Mining                                    4
# Memory Management                                                   4
# Network Security                                                    4
# Graph Theory                                                        4
# Syntax Analysis                                                     4
# Approaches to AI                                                    3
# Context Free Language                                               3
# Data Representation                                                 2
# SQL                                                                 2
# Mobile Technology                                                   2
# Cloud Computing and IoT                                             2
# Fuzzy Sets                                                          2
# ...

# %%
df_dsa = df[df['topic'] == 'Data Structures']
df_dsa
# Out:
#     question_no                                           question  \
# 18           46  The matrix contains m rows and n columns. The ...
# 37           96  Which of the following is useful in implementi...
# 47           26          The prefix form of A – B / (C * D ^ E) is
# 69           53         Which of the following statement is wrong?
# 73           57  In a stack, if an user tries to remove an elem...
# 93           83  Which of the following is not the method to re...
#
#                                         option_a  \
# 18   total number of zero elements > (m * n) / 2
# 37                                         Stack
# 47                                  - /* ^ ABCDE
# 69  In B+ tree data pointers only at leaf nodes.
# 73                                      Overflow
# 93                                         Array
#
#                                              option_b  \
# 18              total number of zero elements = m + n
# ...
